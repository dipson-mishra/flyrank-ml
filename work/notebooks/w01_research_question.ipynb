# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dipson-mishra/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane:** CTR / Engagement Opportunity Scoring.
#
# **Why:** I have chosen this lane because CTR (Click-Through Rate) is a direct measurement of how well a page's search snippet matches user intent. A page with high impressions but low CTR indicates a "visibility-engagement gap"—the page is being seen, but users aren't clicking. This represents a clear, actionable opportunity to improve titles and meta-descriptions to capture existing demand without needing to fight for higher rankings first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** "Which high-visibility pages are under-capturing clicks and should be prioritized for metadata or snippet optimization?"
#
# **Action:** An editor reviews the page's current search snippet and compares it to the top-ranking competitors. They then rewrite the title tag or meta description to better align with the target query's intent and improve the click-incentive.
#
# **Cost of a wrong call:** The cost is wasted editorial time spent optimizing a page where the low CTR is due to a fundamental lack of interest in the content, or where the snippet is already optimal and the low CTR is an inherent property of the query (e.g., a "zero-click" query where the answer is provided on the SERP).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Looking at the starter dataset, there is a massive volume of pages with significant exposure (impressions) but very low engagement. A large portion of the visible inventory has a CTR well below 0.5%, suggesting a systemic opportunity to improve the "capture rate" of existing search visibility.

# %%
import os
import pandas as pd

# Self-contained path resolution: works no matter what cell ran before,
# and no matter what folder Jupyter happens to launch from.
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, "..", ".."))
csv_path = os.path.join(project_root, "data", "raw", "content_refresh_anonymized.csv")

df = pd.read_csv(csv_path)

# Define 'visible' as pages with at least 500 impressions in 90 days
visible = df[df['impressions_90d'] >= 500]
# Identify 'under-capturing' pages as those with CTR < 0.5%
low_ctr = visible[visible['ctr'] < 0.5]

print(f"Total visible pages (imp >= 500): {len(visible)}")
print(f"Pages with low CTR (<0.5%): {len(low_ctr)}")
print(f"Avg CTR of all visible pages: {visible['ctr'].mean():.2f}%")
print(f"Avg CTR of low-CTR visible pages: {low_ctr['ctr'].mean():.2f}%")
# Out:
# Total visible pages (imp >= 500): 16726
# Pages with low CTR (<0.5%): 14245
# Avg CTR of all visible pages: 0.26%
# Avg CTR of low-CTR visible pages: 0.16%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# **What I can claim:**
# - My results are **observed** and **measured** using the anonymized starter dataset.
# - I can identify a **directional** link between certain content attributes and low CTR relative to visibility.
# - This analysis provides **decision-support** for prioritizing metadata reviews.
#
# **What I cannot claim:**
# - I cannot claim that rewriting a meta-description **guarantees** a CTR increase (this would require A/B testing).
# - I cannot claim that low CTR is **caused** by the snippet alone; it could be due to brand perception or competitor dominance.
# - I cannot claim to have decoded the **Google Ranking Algorithm**; I am analyzing observed click behavior.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
